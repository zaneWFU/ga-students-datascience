# %%
import pandas as pd
import numpy as np
import json
from spacy.en import English
import sklearn 
nlp = English()
# %matplotlib inline

data = pd.read_csv("C:\Users\Zane_Harris\Desktop\HRIS files\HRIS\Attrition Study\Primary Data\Global_Base_IBP_STI_Rollup_November2015.csv")
data.head()
# Out:
#     BADGE                           NAME  BIRTHDATE GENDER   HIRE_DATE  \
# 0  100973  Taylor Petersen, Rebecca Jane  3/19/1975      F  12/10/2012
# 1  101177                  Piera, Tomasz  7/24/1966      M  10/15/2012
# 2  104847                 Geary, Suzanne  5/28/1973      F  10/26/2012
# 3   10623              Braselton, Tom C.  2/21/1971      M   9/10/2012
# 4  107585                   Boland, Mike  6/18/1973      M   3/19/2013
#
#    LENGTH OF TENURE AGE AT HIRE COUNTRY HIR_REH JOBCODE_AT_HIRE  \
# 0               461       37.21     AUS     HIR          ADS402
# 1               714       45.59     POL     REH          PAM101
# 2                12       38.87     IRL     REH          PNE800
# 3               958       40.98     USA     REH          SDV800
# 4               375       39.21     IRL     REH          PGV801
#
#             ...           DIT_LVL2_SUP_ID     DIT_LVL2_SUP_NAME  \
# 0           ...                    950329            See, Peter
# 1           ...                    957382      Kowalski, Tomasz
# 2           ...                    304310  Patanella, Todd Earl
# 3           ...                    291049         Dandrow, Paul
# 4           ...                    195935     Kaushik, Abhilash
#
#   DIT_LVL3_SUP_ID  DIT_LVL3_SUP_NAME  DIT_FUNC_DIR_ID     DIT_FUNC_DIR_NAME  \
# 0          910294     Ansah, Michael           950329            See, Peter
# 1           88295           Li, York
# 2          175606    Poljan, Patrick           304310  Patanella, Todd Earl
# 3          535813  Raghavan, Veera S           535813     Raghavan, Veera S
# 4          196486     Thomas, Stanly
#
#   DIT_FUNC_VP_ID          DIT_FUNC_VP_NAME DIT_2LVL_VP_ID  \
# 0         910294            Ansah, Michael          15042
# 1          88295                  Li, York         308394
# 2         175606           Poljan, Patrick          22072
# 3         364711                 Nair, Sid         353428
# 4         536680  Ramamurthy, Ramakrishnan         674834
#
#          DIT_2LVL_VP_NAME
# 0         Price, Steve H.
# 1  Dundas, Michael Blaine
# 2         Brown, Kevin M.
# 3         Vaswani, Suresh
# 4       Thrikutam, Prasad
#
# [5 rows x 53 columns]
